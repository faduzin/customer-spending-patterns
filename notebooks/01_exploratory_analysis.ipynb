# %%
# Importando o módulo src
import sys 
sys.path.append("../")
from src import *

# %% [markdown]
# # Iris Dataset

# %%
df = load_dataframe("../data/raw/Iris.csv") # Carregando o dataframe
# Out:
# Dataframe carregado com sucesso.

# %%
dataframe_info(df) # Exibindo informações do dataframe
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# ...

# %%
for column in df.columns: # Para cada coluna do dataframe
    plot_boxplot_and_histogram(df, column) # Exibir boxplot e histograma

# %%
preprocessed_df = data_preprocess(df, 
                                  remove_outliers=False, 
                                  dataset_name="Iris", 
                                  label_encode=True) # Pré-processando o dataframe
# Out:
# Colunas remapeadas usando Label Encode.
# Pré-processamento bem sucedido.

# %%
save_dataframe(preprocessed_df, "../data/processed/preprocessed_iris.csv") # Salvando o dataframe pré-processado
# Out:
# Arquivo salvo em: ../data/processed/preprocessed_iris.csv.

# %% [markdown]
# # Mall Customers Dataset

# %%
df = load_dataframe("../data/raw/Mall_Customers.csv") # Carregando o dataframe
# Out:
# Dataframe carregado com sucesso.

# %%
dataframe_info(df) # Exibindo informações do dataframe
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# ...

# %%
df = df.rename(columns={
    "Annual Income (k$)":"Annual Income",
    "Spending Score (1-100)":"Spending Score"
}) # Renomeando as colunas

# %%
interesting_columns = ['Age', 'Annual Income', 'Spending Score'] # Colunas interessantes
for column in interesting_columns: # Para cada coluna interessante
    plot_boxplot_and_histogram(df, column) # Exibir boxplot e histograma

# %%
preprocessed_df = data_preprocess(df, 
                                  label_encode=True, 
                                  dataset_name="Mall Customers") # Pré-processando o dataframe
# Out:
# Foram removidas 2 linhas.
# Colunas remapeadas usando Label Encode.
# Pré-processamento bem sucedido.

# %%
save_dataframe(preprocessed_df, "../data/processed/preprocessed_mall_customers.csv") # Salvando o dataframe pré-processado
# Out:
# Arquivo salvo em: ../data/processed/preprocessed_mall_customers.csv.
